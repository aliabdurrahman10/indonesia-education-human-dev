# %% [markdown]
# # Judul - Judul Dataset yang digunakan
#
# ## Dataset 1 : **Rata-Rata Lama Sekolah Berdasarkan Provinsi di Indonesia**
#
# ## Deskripsi
# Dataset ini berisi data rata-rata lama sekolah berdasarkan Provinsi di Indonesia dari tahun 2010 s.d. 2024. Dataset terkait topik Pendidikan ini dihasilkan oleh Badan Pusat Statistik yang dikeluarkan dalam periode 1 tahun sekali.
#
#
# ## Variabel dalam Dataset
#
# | Variabel              | Deskripsi                                                                 |
# |------------------------|---------------------------------------------------------------------------|
# | **kode_provinsi**      | Menyatakan kode dari setiap Provinsi di Indonesia sesuai ketentuan BPS merujuk pada aturan Keputusan Kepala BPS Nomor 649 tahun 2023 dengan tipe data **numerik**. |
# | **nama_provinsi**      | Menyatakan lingkup data berasal dari wilayah Provinsi di Indonesia sesuai ketentuan BPS merujuk pada aturan Keputusan Kepala BPS Nomor 649 tahun 2023 dengan tipe data **teks**. |
# | **rata_rata_lama_sekolah** | Menyatakan nilai rata-rata lama sekolah dengan tipe data **numerik**. |
# | **satuan**             | Menyatakan satuan dari pengukuran rata-rata lama sekolah dalam tahun dengan tipe data **teks**. |
# | **tahun**              | Menyatakan tahun produksi data dengan tipe data **numerik**. |
#
#
# ---
#
# ## Informasi Dataset
#
# - **Dataset Diperbarui**: 15 Mei 2025 14:02:44
# - **Dataset Dibuat**: 28 Februari 2021 22:52:39
# - **Bidang Urusan**: Pendidikan
# - **Cakupan Dataset**: Seluruh Provinsi di Indonesia
# - **Definisi**: Rata-rata lamanya masa yang dilalui dalam menjalani pendidikan formal.
# - **Dimensi Dataset Awal**: 2010
# - **Dimensi Dataset Akhir**: 2024
# - **Frekuensi Dataset**: Tahunan
#
# ---
#
# ## Kontak & Penanggung Jawab
# - **Kontak Produsen**: (022) 7272595 — bps3200@bps.go.id
# - **Penanggung Jawab**: None
#
# ---
#
# ## Detail Teknis
# - **Pengukuran Dataset**: Rata-Rata Lama Sekolah
# - **Produsen**: Badan Pusat Statistik
# - **Satuan Dataset**: Tahun
# - **Tingkat Penyajian Dataset**: Provinsi

# %% [markdown]
# ## Dataset 2 : **Indeks Pembangunan Manusia Berdasarkan Provinsi di Indonesia**
#
# ## Deskripsi
# Dataset ini berisi data indeks pembangunan manusia berdasarkan Provinsi di Indonesia dari tahun 2010 s.d. 2024. Dataset terkait topik **Kependudukan** ini dihasilkan oleh Badan Pusat Statistik yang dikeluarkan dalam periode 1 tahun sekali.
#
# ## Variabel dalam Dataset
#
# | Variabel                     | Deskripsi                                                                 |
# |-------------------------------|---------------------------------------------------------------------------|
# | **kode_provinsi**             | Menyatakan kode dari setiap Provinsi di Indonesia sesuai ketentuan BPS merujuk pada aturan Keputusan Kepala BPS Nomor 649 tahun 2023 dengan tipe data **numerik**. |
# | **nama_provinsi**             | Menyatakan lingkup data berasal dari wilayah Provinsi di Indonesia sesuai ketentuan BPS merujuk pada aturan Keputusan Kepala BPS Nomor 649 tahun 2023 dengan tipe data **teks**. |
# | **indeks_pembangunan_manusia**| Menyatakan nilai indeks pembangunan manusia berdasarkan provinsi dengan tipe data **numerik**. |
# | **satuan**                    | Menyatakan satuan dari pengukuran indeks pembangunan manusia dalam **poin** dengan tipe data **teks**. |
# | **tahun**                     | Menyatakan tahun produksi data dengan tipe data **numerik**. |
#
# ---
#
# ## Informasi Dataset
#
# - **Dataset Diperbarui**: 28 Februari 2025 09:42:55
# - **Dataset Dibuat**: 28 Februari 2021 22:52:03
# - **Bidang Urusan**: Administrasi Kependudukan dan Pencatatan Sipil
# - **Cakupan Dataset**: Seluruh Provinsi di Indonesia
# - **Definisi**: Indeks Pembangunan Manusia berdasarkan provinsi.
# - **Dimensi Dataset Awal**: 2010
# - **Dimensi Dataset Akhir**: 2024
# - **Frekuensi Dataset**: Tahunan
#
# ---
#
# ## Kontak & Penanggung Jawab
# - **Kontak Produsen**: (022) 7272595 — bps3200@bps.go.id
# - **Penanggung Jawab**: None
#
# ---
#
# ## Detail Teknis
# - **Pengukuran Dataset**: Indeks Pembangunan Manusia
# - **Produsen**: Badan Pusat Statistik
# - **Satuan Dataset**: Poin
# - **Tingkat Penyajian Dataset**: Provinsi

# %% [markdown]
# ## Dataset 3 : **Persentase Penduduk Miskin Berdasarkan Provinsi di Indonesia**
#
# ## Deskripsi
# Dataset ini berisi data persentase penduduk miskin berdasarkan semester dan Provinsi di Indonesia dari tahun 2010 s.d. 2024. Dataset terkait topik **Kemiskinan** ini dihasilkan oleh Badan Pusat Statistik yang dikeluarkan dalam periode 1 semesteran, dua kali dalam 1 tahun.
#
# ## Variabel dalam Dataset
#
# | Variabel                     | Deskripsi                                                                 |
# |-------------------------------|---------------------------------------------------------------------------|
# | **kode_provinsi**             | Menyatakan kode dari setiap Provinsi di Indonesia sesuai ketentuan BPS merujuk pada aturan Keputusan Kepala BPS Nomor 649 tahun 2023 dengan tipe data **numerik**. |
# | **nama_provinsi**             | Menyatakan lingkup data berasal dari wilayah Provinsi di Indonesia sesuai ketentuan BPS merujuk pada aturan Keputusan Kepala BPS Nomor 649 tahun 2023 dengan tipe data **teks**. |
# | **persentase_penduduk_miskin**| Menyatakan nilai persentase penduduk miskin dengan tipe data **numerik**. |
# | **satuan**                    | Menyatakan satuan dari pengukuran persentase penduduk miskin dalam **persen** dengan tipe data **teks**. |
# | **tahun**                     | Menyatakan tahun produksi data dengan tipe data **numerik**. |
#
# ---
#
# ## Informasi Dataset
#
# - **Dataset Diperbarui**: 27 Agustus 2024 13:57:00
# - **Dataset Dibuat**: 27 Agustus 2024 13:53:55
# - **Bidang Urusan**: Sosial
# - **Cakupan Dataset**: Seluruh Provinsi di Indonesia
# - **Definisi**: Persentase penduduk miskin berdasarkan provinsi.
# - **Dimensi Dataset Awal**: 2010
# - **Dimensi Dataset Akhir**: 2024
# - **Frekuensi Dataset**: Semesteran (dua kali setahun)
#
# ---
#
# ## Kontak & Penanggung Jawab
# - **Kontak Produsen**: (022) 7272595 — bps3200@bps.go.id
# - **Penanggung Jawab**: None
#
# ---
#
# ## Detail Teknis
# - **Pengukuran Dataset**: Persentase Penduduk Miskin
# - **Produsen**: Badan Pusat Statistik
# - **Satuan Dataset**: Persen
# - **Tingkat Penyajian Dataset**: Provinsi

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# # Load Data

# %%
# Dataset 1 : Rata-rata Lama Sekolah
df = pd.read_csv('bps-od_15058_rata_rata_lama_sekolah__prov_di_indonesia_v3_data.csv')

# %%
# Dataset 2 : Persentase Penduduk Miskin
df2 = pd.read_csv("bps-od_20948_persentase_penduduk_miskin__prov_di_indonesia_v2_data.csv")

# %%
# Dataset 3 : Indeks Pembangunan Manusia (IPM)
df3 = pd.read_csv('bps-od_15042_indeks_pmbngnn_manusia__prov_di_indonesia_data.csv')

# %%
# Dataset 4 : Produk Domestik Regional Bruto (PDRB per Kapita)
df4 = pd.read_csv('bps-od_20211_produk_dmstk_regional_bruto_pdrb_per_kapita_dasar__data.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df
# Out:
#       id  kode_provinsi     nama_provinsi  rata_rata_lama_sekolah satuan  \
# 0      1             11              ACEH                    8.28  TAHUN
# 1      2             12    SUMATERA UTARA                    8.51  TAHUN
# 2      3             13    SUMATERA BARAT                    8.13  TAHUN
# 3      4             14              RIAU                    8.25  TAHUN
# 4      5             15             JAMBI                    7.34  TAHUN
# ..   ...            ...               ...                     ...    ...
# 509  510             92  PAPUA BARAT DAYA                    8.39  TAHUN
# 510  511             94             PAPUA                    9.82  TAHUN
# 511  512             95     PAPUA SELATAN                    8.38  TAHUN
# 512  513             96      PAPUA TENGAH                    6.12  TAHUN
# 513  514             97  PAPUA PEGUNUNGAN                    4.21  TAHUN
#
#      tahun
# 0     2010
# 1     2010
# 2     2010
# 3     2010
# 4     2010
# ..     ...
# ...

# %%
df2
# Out:
#       id  kode_provinsi     nama_provinsi  persentase_penduduk_miskin  satuan  \
# 0      1             11              ACEH                       19.95  PERSEN
# 1      2             12    SUMATERA UTARA                       11.36  PERSEN
# 2      3             13    SUMATERA BARAT                        9.44  PERSEN
# 3      4             14              RIAU                       10.01  PERSEN
# 4      5             15             JAMBI                        8.40  PERSEN
# ..   ...            ...               ...                         ...     ...
# 565  566             92  PAPUA BARAT DAYA                       18.13  PERSEN
# 566  567             94             PAPUA                       17.26  PERSEN
# 567  568             95     PAPUA SELATAN                       17.44  PERSEN
# 568  569             96      PAPUA TENGAH                       29.76  PERSEN
# 569  570             97  PAPUA PEGUNUNGAN                       32.97  PERSEN
#
#      tahun
# 0     2010
# ...

# %%
df3
# Out:
#       id  kode_provinsi     nama_provinsi  indeks_pembangunan_manusia satuan  \
# 0      1             11              ACEH                       67.09   POIN
# 1      2             12    SUMATERA UTARA                       67.09   POIN
# 2      3             13    SUMATERA BARAT                       67.25   POIN
# 3      4             14              RIAU                       68.65   POIN
# 4      5             15             JAMBI                       65.39   POIN
# ..   ...            ...               ...                         ...    ...
# 509  510             92  PAPUA BARAT DAYA                       68.63   POIN
# 510  511             94             PAPUA                       73.00   POIN
# 511  512             95     PAPUA SELATAN                       67.90   POIN
# 512  513             96      PAPUA TENGAH                       59.75   POIN
# 513  514             97  PAPUA PEGUNUNGAN                       53.42   POIN
#
#      tahun
# 0     2010
# 1     2010
# ...

# %%
df4
# Out:
#       id  kode_provinsi     nama_provinsi  pdrb_per_kapita       satuan  tahun
# 0      1             11              ACEH         26851.88  RIBU RUPIAH   2016
# 1      2             12    SUMATERA UTARA         44392.46  RIBU RUPIAH   2016
# 2      3             13    SUMATERA BARAT         37284.56  RIBU RUPIAH   2016
# 3      4             14              RIAU        104861.11  RIBU RUPIAH   2016
# 4      5             15             JAMBI         49494.98  RIBU RUPIAH   2016
# ..   ...            ...               ...              ...          ...    ...
# 309  310             92  PAPUA BARAT DAYA         59063.54  RIBU RUPIAH   2024
# 310  311             94             PAPUA         81009.15  RIBU RUPIAH   2024
# 311  312             95     PAPUA SELATAN         61583.45  RIBU RUPIAH   2024
# 312  313             96      PAPUA TENGAH        118773.53  RIBU RUPIAH   2024
# 313  314             97  PAPUA PEGUNUNGAN         18105.38  RIBU RUPIAH   2024
#
# [314 rows x 6 columns]

# %% [markdown]
# ### Cek Tipe Data, Missing Values, Unique Values

# %%
missing_summary = df.isnull().sum()
data_types = df.dtypes
unique_values = df.nunique()

# Gabungkan dalam satu tabel ringkasan
overview = pd.DataFrame({
    'Data Type': data_types,
    'Missing Values': missing_summary,
    'Unique Values': unique_values
})

overview
# Out:
#                        Data Type  Missing Values  Unique Values
# id                         int64               0            514
# kode_provinsi              int64               0             38
# nama_provinsi             object               0             38
# rata_rata_lama_sekolah   float64               0            288
# satuan                    object               0              1
# tahun                      int64               0             15

# %% [markdown]
# ### Cek info dataset

# %%
rows, cols = df.shape
print(f"Jumlah baris: {rows} dan jumlah kolom: {cols}")
# Out:
# Jumlah baris: 514 dan jumlah kolom: 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      514 non-null    int64
#  1   kode_provinsi           514 non-null    int64
#  2   nama_provinsi           514 non-null    object
#  3   rata_rata_lama_sekolah  514 non-null    float64
#  4   satuan                  514 non-null    object
#  5   tahun                   514 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 24.2+ KB

# %% [markdown]
# ### Ambil Contoh satu provinsi, misal JAWA BARAT

# %%
# filter hanya  provinsi JAWA BARAT, langsung dengan boolean indexing
df_jabar = df[df["nama_provinsi"] == "JAWA BARAT"]
df_jabar
# Out:
#       id  kode_provinsi nama_provinsi  rata_rata_lama_sekolah satuan  tahun
# 11    12             32    JAWA BARAT                    7.40  TAHUN   2010
# 45    46             32    JAWA BARAT                    7.46  TAHUN   2011
# 79    80             32    JAWA BARAT                    7.52  TAHUN   2012
# 113  114             32    JAWA BARAT                    7.58  TAHUN   2013
# 147  148             32    JAWA BARAT                    7.71  TAHUN   2014
# 181  182             32    JAWA BARAT                    7.86  TAHUN   2015
# 215  216             32    JAWA BARAT                    7.95  TAHUN   2016
# 249  250             32    JAWA BARAT                    8.14  TAHUN   2017
# 283  284             32    JAWA BARAT                    8.15  TAHUN   2018
# 317  318             32    JAWA BARAT                    8.37  TAHUN   2019
# 351  352             32    JAWA BARAT                    8.55  TAHUN   2020
# ...

# %%
# filter hanya  provinsi JAWA BARAT, langsung dengan boolean indexing
df_jabar2 = df2[df2["nama_provinsi"] == "JAWA BARAT"]
df_jabar2
# Out:
#       id  kode_provinsi nama_provinsi  persentase_penduduk_miskin  satuan  \
# 11    12             32    JAWA BARAT                       10.93  PERSEN
# 49    50             32    JAWA BARAT                       10.57  PERSEN
# 87    88             32    JAWA BARAT                        9.88  PERSEN
# 125  126             32    JAWA BARAT                        9.61  PERSEN
# 163  164             32    JAWA BARAT                        9.18  PERSEN
# 201  202             32    JAWA BARAT                        9.53  PERSEN
# 239  240             32    JAWA BARAT                        8.95  PERSEN
# 277  278             32    JAWA BARAT                        8.71  PERSEN
# 315  316             32    JAWA BARAT                        7.45  PERSEN
# 353  354             32    JAWA BARAT                        6.91  PERSEN
# 391  392             32    JAWA BARAT                        7.88  PERSEN
# 429  430             32    JAWA BARAT                        8.40  PERSEN
# ...

# %%
# filter hanya  provinsi JAWA BARAT, langsung dengan boolean indexing
df_jabar3 = df3[df3["nama_provinsi"] == "JAWA BARAT"]
df_jabar3
# Out:
#       id  kode_provinsi nama_provinsi  indeks_pembangunan_manusia satuan  \
# 11    12             32    JAWA BARAT                       66.15   POIN
# 45    46             32    JAWA BARAT                       66.67   POIN
# 79    80             32    JAWA BARAT                       67.32   POIN
# 113  114             32    JAWA BARAT                       68.25   POIN
# 147  148             32    JAWA BARAT                       68.80   POIN
# 181  182             32    JAWA BARAT                       69.50   POIN
# 215  216             32    JAWA BARAT                       70.05   POIN
# 249  250             32    JAWA BARAT                       70.69   POIN
# 283  284             32    JAWA BARAT                       71.30   POIN
# 317  318             32    JAWA BARAT                       72.03   POIN
# 351  352             32    JAWA BARAT                       72.09   POIN
# 385  386             32    JAWA BARAT                       72.45   POIN
# ...

# %%
# # Buat DataFrame khusus Jawa Barat (df_jabar) dari df
# df_jabar['persentase_kemiskinan'] = list(df2[df2['nama_provinsi'].str.contains('JAWA BARAT')]['persentase_penduduk_miskin']) 
# df_jabar['indeks_pembangunan_manusia'] = list(df3[df3['nama_provinsi'].str.contains('JAWA BARAT')]['indeks_pembangunan_manusia']) 
# # df_jabar.drop('persentase_penduduk_miskin', axis = 1, inplace=True) 
# df_jabar

# %%
# Buat DataFrame khusus Jawa Barat (df_jabar) dari df
# mulai dari Jabar di df (Rata-rata Lama Sekolah)
df_jabar = df.loc[df['nama_provinsi'] == 'JAWA BARAT', ['nama_provinsi','tahun','rata_rata_lama_sekolah']].copy()

# gabung dengan kemiskinan
df_jabar = df_jabar.merge(
    df2.loc[df2['nama_provinsi'] == 'JAWA BARAT', ['nama_provinsi','tahun','persentase_penduduk_miskin']],
    on=['nama_provinsi','tahun'], how='left'
)

# gabung dengan IPM
df_jabar = df_jabar.merge(
    df3.loc[df3['nama_provinsi'] == 'JAWA BARAT', ['nama_provinsi','tahun','indeks_pembangunan_manusia']],
    on=['nama_provinsi','tahun'], how='left'
).sort_values('tahun')
df_jabar
# Out:
#    nama_provinsi  tahun  rata_rata_lama_sekolah  persentase_penduduk_miskin  \
# 0     JAWA BARAT   2010                    7.40                       10.93
# 1     JAWA BARAT   2011                    7.46                       10.57
# 2     JAWA BARAT   2012                    7.52                        9.88
# 3     JAWA BARAT   2013                    7.58                        9.61
# 4     JAWA BARAT   2014                    7.71                        9.18
# 5     JAWA BARAT   2015                    7.86                        9.53
# 6     JAWA BARAT   2016                    7.95                        8.95
# 7     JAWA BARAT   2017                    8.14                        8.71
# 8     JAWA BARAT   2018                    8.15                        7.45
# 9     JAWA BARAT   2019                    8.37                        6.91
# 10    JAWA BARAT   2020                    8.55                        7.88
# ...

# %% [markdown]
# ## 1. Korelasi **Rata-Rata Lama Sekolah** dan **Tingkat Kemiskinan** (Provinsi Jawa Barat)

# %%
sns.regplot(data=df_jabar, x="persentase_penduduk_miskin", y="rata_rata_lama_sekolah")
# Out:
# <Axes: xlabel='persentase_penduduk_miskin', ylabel='rata_rata_lama_sekolah'>

# %% [markdown]
# ## Interpretasi Regresi: `persentase_penduduk_miskin` (X) vs `rata_rata_lama_sekolah` (Y) – df_jabar
#
# - **Arah hubungan:** Garis regresi miring ke **bawah** → terdapat **hubungan negatif**.
#   Artinya, **semakin tinggi persentase penduduk miskin, semakin rendah rata-rata lama sekolah**.
#
# - **Kekuatan & ketidakpastian:** Pita biru (confidence band) cukup **lebar** di beberapa rentang X → ada **ketidakpastian** dan sebaran data yang tidak sepenuhnya rapat di garis. Hubungan negatifnya jelas secara visual, tetapi **kekuatan pastinya perlu dicek** dengan metrik (mis. koefisien, p-value, dan R²).
#
# - **Sebaran titik:** Titik-titik menyebar di sekitar garis dengan pola menurun; ada beberapa titik yang agak menjauh (calon **outlier**) yang bisa mempengaruhi kemiringan garis.
#
# - **Interpretasi substantif (Jawa Barat):** Pada kab/kota di Jabar, wilayah dengan **kemiskinan lebih tinggi cenderung memiliki lama sekolah lebih pendek**. Ini konsisten dengan literatur bahwa kondisi ekonomi mempengaruhi akses/keberlanjutan sekolah.
#
# - **Catatan penting:** Plot ini menunjukkan **asosiasi**, bukan **kausalitas**. Untuk klaim kausal (mis. “menurunkan kemiskinan meningkatkan lama sekolah”), gunakan pendekatan ekonometrika (mis. **2SLS** dengan instrumen/lag) seperti pada bagian metode simultan.
#
# > Rekomendasi tindak lanjut: hitung **koefisien regresi, p-value, dan R²** untuk mengkuantifikasi kekuatan hubungan; pertimbangkan kontrol (PDRB per kapita, urbanisasi, dll.) dan uji robustnes (outlier, heteroskedastisitas).

# %%
sns.heatmap(df_jabar[['persentase_penduduk_miskin',"rata_rata_lama_sekolah" ]].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Interpretasi Heatmap Korelasi (df_jabar)
#
# - **Nilai diagonal = 1** → korelasi variabel dengan dirinya sendiri.
# - **Korelasi `persentase_penduduk_miskin` vs `rata_rata_lama_sekolah` = −0.86**
#   - **Arah:** negatif (semakin tinggi kemiskinan → semakin rendah rata-rata lama sekolah).
#   - **Kekuatan:** sangat kuat (mendekati −1).
#   - **Makna praktis (Jabar):** kab/kota dengan kemiskinan lebih tinggi cenderung memiliki lama sekolah lebih pendek.
#
# > Catatan:
# > - Ini **asosiasi**, bukan bukti kausal. Untuk inferensi kausal gunakan 2SLS/IV sebagaimana pada model simultan.
# > - Periksa **outlier**, **linearitas**, dan **ukuran sampel**; korelasi sensitif terhadap hal-hal tersebut.

# %% [markdown]
# ## 2. Korelasi **Rata-Rata Lama Sekolah** dan **Indeks Pembangunan Manusia** (Provinsi Jawa Barat)

# %%
sns.regplot(data=df_jabar, x="indeks_pembangunan_manusia", y="rata_rata_lama_sekolah")
# Out:
# <Axes: xlabel='indeks_pembangunan_manusia', ylabel='rata_rata_lama_sekolah'>

# %% [markdown]
# ## Interpretasi Regplot: `indeks_pembangunan_manusia` (X) vs `rata_rata_lama_sekolah` (Y) – df_jabar
#
# - **Arah hubungan:** Garis tren **menanjak tajam** → **korelasi positif kuat**.
#   Semakin tinggi **IPM**, semakin panjang **rata-rata lama sekolah**.
#
# - **Kekuatan hubungan:** Titik-titik menempel rapat di sekitar garis dan pita CI sempit → **linearitas jelas** dan **ketidakpastian kecil** (dugaan R² tinggi).
#
# - **Outlier/noise:** Hampir tidak terlihat outlier mencolok; sebaran relatif homogen di sepanjang rentang IPM.
#
# - **Makna substantif (Jawa Barat):** Daerah dengan kualitas pembangunan manusia lebih baik cenderung memiliki durasi sekolah yang lebih lama.
#
# > Catatan:
# > - Ini **asosiasi**, bukan bukti kausal. Secara teoritis, pendidikan (RLS) juga mendorong IPM, sehingga untuk inferensi arah kausal gunakan pendekatan **simultan/2SLS** dengan instrumen.
# > - Rekomendasi: hitung **koefisien regresi, p-value, Pearson r, dan R²** untuk mengkuantifikasi kekuatan hubungan.

# %%
sns.heatmap(df_jabar[['indeks_pembangunan_manusia',"rata_rata_lama_sekolah" ]].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Interpretasi Heatmap Korelasi: `indeks_pembangunan_manusia` vs `rata_rata_lama_sekolah` (df_jabar)
#
# - **Nilai korelasi = +0.98** → **sangat kuat dan positif**.
#   Semakin tinggi **IPM**, semakin panjang **rata-rata lama sekolah**.
#
# - **Implikasi statistik:**
#   - Hubungan hampir sempurna → kedua variabel **sangat sejalan**.
#   - Potensi **multikolinearitas** tinggi jika keduanya dimasukkan bersamaan sebagai prediktor dalam model regresi.
#
# - **Catatan substantif penting (konteks Indonesia):**
#   - Komponen **pendidikan (termasuk rata-rata lama sekolah)** adalah bagian dari perhitungan **IPM** → wajar korelasinya sangat tinggi (bisa terjadi **korelasi “mekanis”**).
#
# - **Rekomendasi praktis:**
#   - Untuk **prediksi**: hindari menaruh kedua variabel sebagai fitur independen secara bersamaan; pilih salah satu/transformasi, atau gunakan teknik yang tahan multikolinearitas.
#   - Untuk **inferensi kausal**: jangan tafsirkan korelasi ini sebagai sebab-akibat langsung. Gunakan pendekatan **simultan/2SLS** atau instrumen yang valid bila ingin mengukur efek pendidikan terhadap IPM secara kausal.

# %% [markdown]
# # 3. Analisis Konvergensi Pendidikan Antar **Seluruh Provinsi** di Indonesia
#
# Tujuan dari analisis konvergensi ini adalah untuk mengetahui apakah pembangunan pendidikan di Indonesia berlangsung secara merata antar provinsi. Dengan melihat tren ketimpangan dan kecepatan pertumbuhan rata-rata lama sekolah, kita bisa menilai apakah provinsi-provinsi yang tertinggal berhasil mengejar provinsi yang lebih maju. Hasil ini penting untuk mengevaluasi efektivitas kebijakan pendidikan nasional, mengidentifikasi wilayah yang masih tertinggal, dan memberikan bukti empiris bagi pengambilan keputusan agar pemerataan pendidikan benar-benar tercapai.

# %% [markdown]
# ### **1. σ-Convergence**
#
# Mengukur apakah standar deviasi antar provinsi menurun dari waktu ke waktu.

# %%
# === σ-Convergence: Standar deviasi antar provinsi dari waktu ke waktu ===
import pandas as pd
import matplotlib.pyplot as plt

# 1) Hitung standar deviasi tiap tahun
sigma = (
    df.groupby("tahun")["rata_rata_lama_sekolah"]
      .std()
      .reset_index(name="std_dev")
)

# 2) Plot tren sigma convergence
plt.figure(figsize=(8,5))
plt.plot(sigma["tahun"], sigma["std_dev"], marker="o", linestyle="-")
plt.xlabel("Tahun")
plt.ylabel("Standar Deviasi RLS antar Provinsi")
plt.title("σ-Convergence Rata-Rata Lama Sekolah (2010–2024)")
plt.grid(True)
plt.show()

# 3) Interpretasi cepat
if sigma["std_dev"].iloc[-1] < sigma["std_dev"].iloc[0]:
    print("HASIL: Gap antar provinsi makin kecil (indikasi σ-convergence).")
else:
    print("❕ Gap antar provinsi tidak mengecil (tidak ada σ-convergence).")
# Out:
# HASIL: Gap antar provinsi makin kecil (indikasi σ-convergence).

# %% [markdown]
# **Apa yang Ditunjukkan Grafik?**
#
# - Grafik menggambarkan **standar deviasi rata-rata lama sekolah antar provinsi** setiap tahun.
# - Di awal (2010–2012), standar deviasi cukup tinggi (sekitar 1.6).
#   → Artinya, ada perbedaan cukup lebar antar provinsi dalam hal lama sekolah.
# - Setelah 2013, terlihat penurunan tajam → standar deviasi stabil di kisaran 0.9–1.0.
# - Dari 2014 sampai 2023, gap antar provinsi relatif kecil dan stabil.
# - Namun, tahun 2024 ada sedikit kenaikan kembali (sekitar 1.2).
#   → Ini bisa jadi karena data terbaru menunjukkan adanya provinsi baru atau dinamika khusus di wilayah tertentu.

# %% [markdown]
# **Beberapa Insight yang Bisa Diambil**
#
# 1. **Konvergensi Pendidikan Terjadi**
#    Penurunan standar deviasi menunjukkan bahwa ketimpangan antar provinsi dalam rata-rata lama sekolah makin mengecil.
#    Dengan kata lain, provinsi-provinsi yang dulu tertinggal mulai mengejar ketertinggalannya.
#
# 2. **Stabilitas Relatif setelah 2013**
#    Setelah 2013, variasi antar provinsi jauh lebih sempit.
#    Hal ini bisa mencerminkan kebijakan nasional (misalnya *Wajib Belajar 12 Tahun*, BOS, pemerataan akses sekolah) yang mulai berdampak.
#
# 3. **Kenaikan Kecil di 2024**
#    Kenaikan di ujung bisa mengindikasikan adanya provinsi yang datanya “ekstrim” dibanding yang lain.
#    Bisa juga karena adanya pemekaran wilayah (misalnya Papua) sehingga perbedaan statistik antar provinsi jadi lebih jelas.

# %% [markdown]
# **Kenapa pakai metode σ-Convergence?**
#
# σ-Convergence adalah metode yang melihat ketimpangan dengan standar deviasi atau varians.
#
# Logikanya sederhana:
#
# - Kalau standar deviasi antar wilayah menurun, artinya perbedaan makin kecil → ada konvergensi.
# - Kalau standar deviasi tetap atau naik, artinya gap antar wilayah tidak mengecil.
#
# Cocok dipakai untuk data panel antar wilayah dan tahun, karena fokusnya memang ke “apakah ketimpangan antar wilayah makin sempit”.

# %% [markdown]
# **Apa relevansi pemilihan metode dengan tujuan penelitian ini?**
#
# Pemerintah sering bicara soal pemerataan pembangunan.
#
# Di bidang pendidikan, bukan cuma **rata-rata nasional** yang penting, tapi juga apakah **provinsi miskin ikut mengejar provinsi kaya**.
#
# Dengan **σ-Convergence**, kita bisa menjawab:
#  *“Apakah pendidikan makin merata?”*
#
# **Hasilnya:** Ya, cukup merata sejak 2013, meski masih ada sedikit lonjakan ketimpangan di tahun 2024.

# %% [markdown]
# ### Jadi kesimpulan akhirnya:
#
# Ketimpangan rata-rata lama sekolah antar provinsi di Indonesia cenderung menurun sejak 2010, menunjukkan adanya konvergensi pendidikan. Walau demikian, data 2024 memberi sinyal bahwa masih ada tantangan pemerataan di beberapa provinsi tertentu.

# %% [markdown]
# ### **2. β-Convergence**
#
# Regresi pertumbuhan terhadap level awal.
# Misalnya: hitung pertumbuhan 2010–2024 → regresikan terhadap level awal 2010.

# %%
# === β-Convergence: growth 2010–2024 terhadap level awal 2010 ===
# ----- 1) Siapkan data dasar hanya kolom yang dipakai
base = (
    df.loc[:, ["nama_provinsi", "tahun", "rata_rata_lama_sekolah"]]
      .dropna(subset=["nama_provinsi", "tahun", "rata_rata_lama_sekolah"])
      .copy()
)

# ----- 2) Ambil tahun awal & akhir (pastikan ada di data)
YEAR0, YEAR1 = 2010, 2024
d0 = base[base["tahun"] == YEAR0].rename(columns={"rata_rata_lama_sekolah": f"RLS_{YEAR0}"})
d1 = base[base["tahun"] == YEAR1].rename(columns={"rata_rata_lama_sekolah": f"RLS_{YEAR1}"})

# ----- 3) Gabungkan by provinsi, simpan hanya provinsi yang punya keduanya
merged = (
    pd.merge(d0[["nama_provinsi", f"RLS_{YEAR0}"]],
             d1[["nama_provinsi", f"RLS_{YEAR1}"]],
             on="nama_provinsi", how="inner")
)

# ----- 4) Bersihkan baris bermasalah: nol/negatif/NaN
mask_valid = (
    merged[f"RLS_{YEAR0}"].gt(0) &
    merged[f"RLS_{YEAR1}"].gt(0) &
    merged[[f"RLS_{YEAR0}", f"RLS_{YEAR1}"]].notna().all(axis=1)
)
bad = merged.loc[~mask_valid]
if not bad.empty:
    print("  data yang row-nya kosong - > Dibuang (nol/NaN/negatif):")
    display(bad)

merged = merged.loc[mask_valid].copy()

# ----- 5) Hitung growth tahunan rata-rata (continuous/CAGR log)
T = YEAR1 - YEAR0
merged["growth"] = (np.log(merged[f"RLS_{YEAR1}"]) - np.log(merged[f"RLS_{YEAR0}"])) / T

# ----- 6) Regresi: growth ~ level awal
X = sm.add_constant(merged[f"RLS_{YEAR0}"])
y = merged["growth"]
model = sm.OLS(y, X).fit(cov_type="HC1")   # robust SE (White/HC1)

print(model.summary())

# ----- 7) Visual bantu: scatter + garis regresi
plt.figure()
plt.scatter(merged[f"RLS_{YEAR0}"], merged["growth"])
# garis regresi
x_line = np.linspace(merged[f"RLS_{YEAR0}"].min(), merged[f"RLS_{YEAR0}"].max(), 100)
y_line = model.params["const"] + model.params[f"RLS_{YEAR0}"] * x_line
plt.plot(x_line, y_line)
plt.xlabel(f"Rata-rata Lama Sekolah {YEAR0}")
plt.ylabel("Pertumbuhan Tahunan (log) 2010–2024")
plt.title("β-convergence: growth vs level awal")
plt.show()

# ----- 8) Cek cepat arah konvergensi
beta = model.params.get(f"RLS_{YEAR0}")
sig  = model.pvalues.get(f"RLS_{YEAR0}")
print(f"\nKoefisien awal (β): {beta:.4f} | p-value: {sig:.4f}")
if np.isfinite(beta) and sig is not None:
    if (beta < 0) and (sig < 0.05):
        print(" Indikasi β-convergence: provinsi dengan level awal lebih rendah tumbuh lebih cepat.")
    else:
        print("❕ Tidak ada bukti kuat β-convergence (atau arahnya tidak negatif).")
# Out:
#   data yang row-nya kosong - > Dibuang (nol/NaN/negatif):
#        nama_provinsi  RLS_2010  RLS_2024
# 23  KALIMANTAN UTARA       0.0      9.35
#                             OLS Regression Results
# ...
# Dep. Variable:                 growth   R-squared:                       0.437
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     7.321
# Date:                Fri, 24 Oct 2025   Prob (F-statistic):             0.0110
# Time:                        11:38:09   Log-Likelihood:                 134.14
# No. Observations:                  33   AIC:                            -264.3
# Df Residuals:                      31   BIC:                            -261.3
# Df Model:                           1
# Covariance Type:                  HC1
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# ## Hasil OLS
#
# **Spesifikasi ringkas**
# - Dependent variable: `growth`
# - N = 33 observasi
# - R-squared = **0,437** → sekitar 44% variasi `growth` dijelaskan model
# - Prob(F-stat) = **0,011** → model **signifikan** sebagai keseluruhan
# - Covariance type = **HC1** → standar error sudah robust terhadap heteroskedastisitas
#
# **Koefisien**
# - `RLS_2010` = **−0,0037** (z = −2,706; **p = 0,007**) → **signifikan negatif**.
#   Tafsir : kenaikan 1 unit `RLS_2010` berkorelasi dengan penurunan `growth` sebesar 0,0037 (ceteris paribus). Tanda negatif ini tidak sejalan dengan ekspektasi  (pendidikan mestinya pro–pertumbuhan), jadi ini red flag.
# - Konstanta = **0,0412** (p < 0,001)
#
# **Diagnostik residual**
# - **Durbin–Watson = 1,587** → indikasi autokorelasi positif ringan.
# - **Omnibus p = 0,000** dan **JB p ≈ 1,12e−60** → residual jauh dari normal (skew 3,145; kurtosis 15,697).
# - **Cond. No = 60,3** → multikolinearitas **sedang** (belum ekstrem, tetap perlu waspada).
#
# **Kesimpulan **
# 1. Secara statistik, model OLS ini lolos uji F, dan `RLS_2010` muncul signifikan.
# 2. Namun tanda koefisien yang negatif + masalah diagnostik membuat  **tidak nyaman** menjadikannya sebagai bukti kausal. Ini sangat mungkin efek **endogenitas/omitted variables** atau definisi/skala variabel.
#
# **Langkah lanjut yang  ambil**
# -  **bandingkan dengan 2SLS/IV** (sesuai rancangan simultan) untuk mengoreksi endogenitas dan melihat apakah tanda/besaran koefisien menjadi lebih masuk akal.
# -  tambahkan **variabel kontrol** (mis. PDRB per kapita/struktur ekonomi) dan cek stabilitas koefisien.
# - Untuk potensi autokorelasi,  pertimbangkan **HAC/Newey–West** atau spesifikasi dinamis.
# -  verifikasi kembali **definisi & skala** `growth` dan `RLS_2010` agar interpretasi unit tepat.
#
# > Intinya: OLS memberi sinyal asosiasi negatif yang signifikan, **tapi** dengan red flag kuat.  tidak menarik kesimpulan kausal dari output ini sebelum koreksi dengan **2SLS**.

# %% [markdown]
# **Apa yang Ditunjukkan Hasil Regresi?**
#
# - **Koefisien RLS_2010 (β) = -0.0037**
#   Artinya, semakin rendah rata-rata lama sekolah di tahun 2010, semakin tinggi pertumbuhan rata-rata lama sekolah selama 2010–2024.
#   Nilai negatif inilah bukti adanya **konvergensi**.
#
# - **p-value = 0.007 (< 0.05)**
#   Koefisien ini signifikan secara statistik. Jadi, pola negatif tadi bukan kebetulan semata, melainkan punya dasar kuat dalam data.
#
# - **R-squared = 0.437**
#   Sekitar 43,7% variasi pertumbuhan bisa dijelaskan oleh level awal 2010.
#   Ini angka moderat, cukup masuk akal untuk data cross-provinsi.
#
# - **const = 0.0412**
#   Nilai ini bisa ditafsirkan sebagai *baseline growth* rata-rata tahunan, sebelum memperhitungkan level awal.

# %% [markdown]
# **Apa yang Ditunjukkan Scatter Plot?**
#
# - Titik-titik di scatter plot mewakili **provinsi**.
# - **Sumbu X**: rata-rata lama sekolah tahun 2010.
# - **Sumbu Y**: pertumbuhan tahunan (log) 2010–2024.
# - Garis regresi menurun → provinsi dengan level awal rendah tumbuh lebih cepat, sedangkan provinsi dengan level awal tinggi tumbuh lebih lambat.
# - **Contoh:** Papua atau NTT (awal rendah) tumbuh lebih pesat dibanding DKI Jakarta (awal tinggi).

# %% [markdown]
# **Insight yang Bisa Diambil**
#
# - **Ada β-Convergence**
#   Hasil ini mendukung hipotesis bahwa provinsi-provinsi yang tertinggal di awal periode 2010 berhasil mengejar ketertinggalannya sampai 2024.
#
# - **Pemerataan Pendidikan Semakin Nyata**
#   Kebijakan nasional seperti *Wajib Belajar 12 Tahun*, BOS, dan pembangunan infrastruktur pendidikan tampaknya membantu provinsi dengan titik awal rendah untuk tumbuh lebih cepat.
#
# - **Masih Ada Variasi yang Tidak Dijelaskan**
#   R-squared hanya 0.437, artinya masih ada faktor lain (misalnya kualitas guru, anggaran daerah, urbanisasi, ekonomi lokal) yang memengaruhi pertumbuhan pendidikan.

# %% [markdown]
# **Alasan memakai Metode β-Convergence?**
#
# **β-Convergence** adalah pendekatan yang melihat hubungan antara level awal dengan pertumbuhan.
#
# - Jika **koefisien negatif signifikan** → daerah yang lebih tertinggal tumbuh lebih cepat → ada **konvergensi**.
# - Metode ini populer dalam studi ekonomi regional (misalnya untuk PDB per kapita, IPM, pendidikan), karena memberi gambaran apakah *“yang tertinggal mengejar yang maju”*.

# %% [markdown]
# ## Kesimpulan
#
# - Hasil regresi dan scatter menunjukkan indikasi kuat **β-Convergence** dalam rata-rata lama sekolah antar provinsi di Indonesia periode 2010–2024.
#
# - Dengan kata lain: provinsi yang awalnya tertinggal justru mengalami pertumbuhan pendidikan yang lebih cepat, sehingga ketimpangan antar provinsi berkurang.
#
# - Temuan ini memperkuat hasil **σ-Convergence** yang dihitung sebelumnya.

# %% [markdown]
# ## Gambaran Besar: σ-Convergence dan β-Convergence
#
# - **σ-Convergence** → ketimpangan antar provinsi makin kecil.
# - **β-Convergence** → provinsi yang awalnya tertinggal memang tumbuh lebih cepat.
